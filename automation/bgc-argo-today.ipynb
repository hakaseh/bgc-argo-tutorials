# %% [markdown]
# # BGC-Argo Today

# %%
import plotly.io as pio
# This forces Plotly to embed the interactive JavaScript engine
# even when the notebook is run by a background bot!
pio.renderers.default = 'notebook_connected'

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from datetime import datetime, timedelta
import plotly.graph_objects as go
import plotly.express as px
import sys
import os

# 1. Get the absolute path to the 'lessons' folder 
# ('..' means "go up one level to the root directory")
lessons_path = os.path.abspath(os.path.join('..', 'lessons'))

# 2. Add that folder to Python's search path
if lessons_path not in sys.path:
    sys.path.append(lessons_path)

# 3. Now your original import will work perfectly!
from ipynb.fs.defs.lesson_1 import load_index, filter_index, calculate_float_speed, filter2_and_save_index
from ipynb.fs.defs.lesson_2 import show_map_timeline
from ipynb.fs.defs.lesson_3 import download_argo

# %%
today = datetime.now().strftime('%Y%m%d')

# %%
lon0 = -180
lon1 = 180
lat0 = -90
lat1 = 90
date0 = today
date1 = today
bgc_parameters = 'CHLA'
mindura = None
minfreq = None
maxdrif = None
note = 'today'
df_index = load_index()
df_filter = filter_index(df_index, lon0, lon1, lat0, lat1, date0, date1, bgc_parameters)
df = filter2_and_save_index(df_filter, mindura, minfreq, maxdrif, note)
# Out:
# Connecting to the French GDAC...
# ✅ Success!
# ../index_files/argo_synthetic-profile_index_today.parquet has been saved...

# %%
show_map_timeline(df,today)
# Out:
#         <script>
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.5.0.min"</script>
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.5.0.min.js" integrity="sha256-fHbNLP+GlIXN+efbQec78UkemUz3NJp7UmfGxC1tNxs=" crossorigin="anonymous"></script>                <div id="7188718c-a425-4f86-8fb9-52857ddcc7c2" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("7188718c-a425-4f86-8fb9-52857ddcc7c2")) {                    Plotly.newPlot(                        "7188718c-a425-4f86-8fb9-52857ddcc7c2",                        [{"customdata":["2026-04-24T11:31:00.000000"],"hovertemplate":"\u003cb\u003eWMO:\u003c\u002fb\u003e 1902602\u003cbr\u003e\u003cb\u003eDate:\u003c\u002fb\u003e %{customdata|%Y-%m-%d %H:%M}\u003cextra\u003e\u003c\u002fextra\u003e","lat":{"dtype":"f8","bdata":"sHJoke0UUEA="},"lon":{"dtype":"f8","bdata":"ke18PzVeFsA="},"marker":{"color":"#636EFA","size":4},"mode":"markers","name":"1902602","type":"scattergeo"},{"hoverinfo":"skip","lat":[64.327],"lon":[-5.592],"marker":{"color":"black","size":8},"mode":"markers+text","showlegend":false,"type":"scattergeo"},{"customdata":["2026-04-24T12:53:22.000000"],"hovertemplate":"\u003cb\u003eWMO:\u003c\u002fb\u003e 1902695\u003cbr\u003e\u003cb\u003eDate:\u003c\u002fb\u003e %{customdata|%Y-%m-%d %H:%M}\u003cextra\u003e\u003c\u002fextra\u003e","lat":{"dtype":"f8","bdata":"5\u002fup8dJNT0A="},"lon":{"dtype":"f8","bdata":"JQaBlUOrS8A="},"marker":{"color":"#EF553B","size":4},"mode":"markers","name":"1902695","type":"scattergeo"},{"hoverinfo":"skip","lat":[62.608],"lon":[-55.338],"marker":{"color":"black","size":8},"mode":"markers+text","showlegend":false,"type":"scattergeo"},{"customdata":["2026-04-24T03:25:22.000000"],"hovertemplate":"\u003cb\u003eWMO:\u003c\u002fb\u003e 2903787\u003cbr\u003e\u003cb\u003eDate:\u003c\u002fb\u003e %{customdata|%Y-%m-%d %H:%M}\u003cextra\u003e\u003c\u002fextra\u003e","lat":{"dtype":"f8","bdata":"ObTIdr7fScA="},"lon":{"dtype":"f8","bdata":"NV66SQxqYUA="},"marker":{"color":"#00CC96","size":4},"mode":"markers","name":"2903787","type":"scattergeo"},{"hoverinfo":"skip","lat":[-51.748],"lon":[139.314],"marker":{"color":"black","size":8},"mode":"markers+text","showlegend":false,"type":"scattergeo"},{"customdata":["2026-04-24T07:25:32.000000"],"hovertemplate":"\u003cb\u003eWMO:\u003c\u002fb\u003e 2904011\u003cbr\u003e\u003cb\u003eDate:\u003c\u002fb\u003e %{customdata|%Y-%m-%d %H:%M}\u003cextra\u003e\u003c\u002fextra\u003e","lat":{"dtype":"f8","bdata":"O99PjZduO0A="},"lon":{"dtype":"f8","bdata":"FK5H4XrkVcA="},"marker":{"color":"#AB63FA","size":4},"mode":"markers","name":"2904011","type":"scattergeo"},{"hoverinfo":"skip","lat":[27.432],"lon":[-87.57],"marker":{"color":"black","size":8},"mode":"markers+text","showlegend":false,"type":"scattergeo"},{"customdata":["2026-04-24T13:18:01.000000"],"hovertemplate":"\u003cb\u003eWMO:\u003c\u002fb\u003e 2904024\u003cbr\u003e\u003cb\u003eDate:\u003c\u002fb\u003e %{customdata|%Y-%m-%d %H:%M}\u003cextra\u003e\u003c\u002fextra\u003e","lat":{"dtype":"f8","bdata":"jZduEoNQREA="},"lon":{"dtype":"f8","bdata":"7FG4HoXrJkA="},"marker":{"color":"#FFA15A","size":4},"mode":"markers","name":"2904024","type":"scattergeo"},{"hoverinfo":"skip","lat":[40.629],"lon":[11.46],"marker":{"color":"black","size":8},"mode":"markers+text","showlegend":false,"type":"scattergeo"},{"customdata":["2026-04-24T05:31:00.000000"],"hovertemplate":"\u003cb\u003eWMO:\u003c\u002fb\u003e 4902598\u003cbr\u003e\u003cb\u003eDate:\u003c\u002fb\u003e %{customdata|%Y-%m-%d %H:%M}\u003cextra\u003e\u003c\u002fextra\u003e","lat":{"dtype":"f8","bdata":"FK5H4Xq0Q0A="},"lon":{"dtype":"f8","bdata":"FK5H4XrUS8A="},"marker":{"color":"#19D3F3","size":4},"mode":"markers","name":"4902598","type":"scattergeo"},{"hoverinfo":"skip","lat":[39.41],"lon":[-55.66],"marker":{"color":"black","size":8},"mode":"markers+text","showlegend":false,"type":"scattergeo"},{"customdata":["2026-04-24T13:36:00.000000"],"ho ...
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.5.0.min.js" integrity="sha256-fHbNLP+GlIXN+efbQec78UkemUz3NJp7UmfGxC1tNxs=" crossorigin="anonymous"></script>                <div id="85f3d49d-3782-401f-b57a-6a4fcbf7e809" class="plotly-graph-div" style="height:400px; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("85f3d49d-3782-401f-b57a-6a4fcbf7e809")) {                    Plotly.newPlot(                        "85f3d49d-3782-401f-b57a-6a4fcbf7e809",                        [{"hovertemplate":"\u003cb\u003eDate:\u003c\u002fb\u003e %{x|%Y-%m-%d %H:%M}\u003cextra\u003e\u003c\u002fextra\u003e","marker":{"color":"#636EFA","line":{"color":"#636EFA","width":1.5},"size":14,"symbol":"line-ns"},"mode":"markers","name":"1902602","x":["2026-04-24T11:31:00.000000"],"y":["1902602"],"type":"scatter"},{"hovertemplate":"\u003cb\u003eDate:\u003c\u002fb\u003e %{x|%Y-%m-%d %H:%M}\u003cextra\u003e\u003c\u002fextra\u003e","marker":{"color":"#EF553B","line":{"color":"#EF553B","width":1.5},"size":14,"symbol":"line-ns"},"mode":"markers","name":"1902695","x":["2026-04-24T12:53:22.000000"],"y":["1902695"],"type":"scatter"},{"hovertemplate":"\u003cb\u003eDate:\u003c\u002fb\u003e %{x|%Y-%m-%d %H:%M}\u003cextra\u003e\u003c\u002fextra\u003e","marker":{"color":"#00CC96","line":{"color":"#00CC96","width":1.5},"size":14,"symbol":"line-ns"},"mode":"markers","name":"2903787","x":["2026-04-24T03:25:22.000000"],"y":["2903787"],"type":"scatter"},{"hovertemplate":"\u003cb\u003eDate:\u003c\u002fb\u003e %{x|%Y-%m-%d %H:%M}\u003cextra\u003e\u003c\u002fextra\u003e","marker":{"color":"#AB63FA","line":{"color":"#AB63FA","width":1.5},"size":14,"symbol":"line-ns"},"mode":"markers","name":"2904011","x":["2026-04-24T07:25:32.000000"],"y":["2904011"],"type":"scatter"},{"hovertemplate":"\u003cb\u003eDate:\u003c\u002fb\u003e %{x|%Y-%m-%d %H:%M}\u003cextra\u003e\u003c\u002fextra\u003e","marker":{"color":"#FFA15A","line":{"color":"#FFA15A","width":1.5},"size":14,"symbol":"line-ns"},"mode":"markers","name":"2904024","x":["2026-04-24T13:18:01.000000"],"y":["2904024"],"type":"scatter"},{"hovertemplate":"\u003cb\u003eDate:\u003c\u002fb\u003e %{x|%Y-%m-%d %H:%M}\u003cextra\u003e\u003c\u002fextra\u003e","marker":{"color":"#19D3F3","line":{"color":"#19D3F3","width":1.5},"size":14,"symbol":"line-ns"},"mode":"markers","name":"4902598","x":["2026-04-24T05:31:00.000000"],"y":["4902598"],"type":"scatter"},{"hovertemplate":"\u003cb\u003eDate:\u003c\u002fb\u003e %{x|%Y-%m-%d %H:%M}\u003cextra\u003e\u003c\u002fextra\u003e","marker":{"color":"#FF6692","line":{"color":"#FF6692","width":1.5},"size":14,"symbol":"line-ns"},"mode":"markers","name":"4902625","x":["2026-04-24T13:36:00.000000"],"y":["4902625"],"type":"scatter"},{"hovertemplate":"\u003cb\u003eDate:\u003c\u002fb\u003e %{x|%Y-%m-%d %H:%M}\u003cextra\u003e\u003c\u002fextra\u003e","marker":{"color":"#B6E880","line":{"color":"#B6E880","width":1.5},"size":14,"symbol":"line-ns"},"mode":"markers","name":"4902683","x":["2026-04-24T02:04:00.000000"],"y":["4902683"],"type":"scatter"},{"hovertemplate":"\u003cb\u003eDate:\u003c\u002fb\u003e %{x|%Y-%m-%d %H:%M}\u003cextra\u003e\u003c\u002fextra\u003e","marker":{"color":"#FF97FF","line":{"color":"#FF97FF","width":1.5},"size":14,"symbol":"line-ns"},"mode":"markers","name":"4902686","x":["2026-04-24T07:56:00.000000"],"y":["4902686"],"type":"scatter"},{"hovertemplate":"\u003cb\u003eDate:\u003c\u002fb\u003e %{x|%Y-%m-%d %H:%M}\u003cextra\u003e\u003c\u002fextra\u003e","marker":{"color":"#FECB52","line":{"color":"#FECB52","width":1.5},"size":14,"symbol":"line-ns"},"mode":"markers","name":"4903614","x":["2026-04-24T14:49:35.000000"],"y":["4903614"],"type":"scatter"},{"hovertemplate":"\u003cb\u003eDate:\u003c\u002fb\u003e %{x|%Y-%m-%d %H:%M}\u003cextra\u003e\u003c\u002fextra\u003e","marker":{"color":"#636EFA","line":{"color":"#636EFA","width":1.5},"size":14,"symbol":"line-ns"},"mode":"mark ...
